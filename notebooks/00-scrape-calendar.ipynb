# %% [markdown]
# # 00 scraping ATP calendar
#
# This currently relies on Selenium and EdgeChromium WebDriver. I also wasn't able to get this working in headless mode.
#
# If you do not have/do not wish to use Edge browser for this, you should be able to run the scraper by changing all EdgeChromium-specific lines in the source code (`infotennis/scrapers/scraping_functions_atp.py`) to your [preferred browser accordingly](https://pypi.org/project/webdriver-manager/).

# %%
import pandas as pd

from infotennis.scrapers.scraping_functions_atp import scrape_ATP_calendar

# %%
df_cal = scrape_ATP_calendar(2023)

# %%
df_cal
# Out:
#     year                tournament tournament_id          category  \
# 0   2023                United Cup          9900             Other
# 1   2023  Adelaide International 1          2843           ATP 250
# 2   2023     Tata Open Maharashtra           891           ATP 250
# 3   2023               ASB Classic           301           ATP 250
# 4   2023  Adelaide International 2          8998           ATP 250
# ..   ...                       ...           ...               ...
# 63  2023       Rolex Paris Masters           352  ATP Masters 1000
# 64  2023              Moselle Open           341           ATP 250
# 65  2023                Sofia Open          7434           ATP 250
# 66  2023          Nitto ATP Finals           605             Other
# 67  2023       Next Gen ATP Finals          7696             Other
#
#                             location  date_start tournament_status  \
# 0   Brisbane-Perth-Sydney, Australia  2022.12.29         Completed
# 1                Adelaide, Australia  2023.01.01         Completed
# 2                        Pune, India  2023.01.02         Completed
# 3              Auckland, New Zealand  2023.01.09         Completed
# 4                Adelaide, Australia  2023.01.09         Completed
# ..                               ...         ...               ...
# 63                     Paris, France  2023.10.30           Ongoing
# 64                      Metz, France  2023.11.05           Ongoing
# 65                   Sofia, Bulgaria  2023.11.06
# 66                      Turin, Italy  2023.11.12
# 67              Jeddah, Saudi Arabia  2023.11.28
#
#              draw       surface      finance  \
# 0   SGL 18 DBL 18  Outdoor Hard  $15,000,000
# 1   SGL 32 DBL 24  Outdoor Hard     $642,735
# 2   SGL 28 DBL 16  Outdoor Hard     $713,495
# 3   SGL 28 DBL 16  Outdoor Hard     $713,495
# 4   SGL 28 DBL 24  Outdoor Hard     $642,735
# ..            ...           ...          ...
# 63  SGL 56 DBL 24   Indoor Hard   €6,748,815
# 64  SGL 28 DBL 16   Indoor Hard     €630,705
# 65  SGL 28 DBL 16   Indoor Hard     €630,705
# 66    SGL 8 DBL 8   Indoor Hard
# 67    SGL 8 DBL 0   Indoor Hard   $2,000,000
#
#                                                winner  \
# 0                                 Team: United States
# 1   SGL: Novak Djokovic, DBL: Lloyd Glasspool Harr...
# 2   SGL: Tallon Griekspoor, DBL: Sander Gille Jora...
# 3   SGL: Richard Gasquet, DBL: Nikola Mektic Mate ...
# 4   SGL: Soonwoo Kwon, DBL: Marcelo Arevalo Jean-J...
# ..                                                ...
# 63
# 64
# 65
# 66
# 67
#
#                                                   url
# 0   https://www.atptour.com/en/scores/archive/bris...
# 1   https://www.atptour.com/en/scores/archive/adel...
# 2   https://www.atptour.com/en/scores/archive/pune...
# 3   https://www.atptour.com/en/scores/archive/auck...
# 4   https://www.atptour.com/en/scores/archive/adel...
# ..                                                ...
# 63  https://www.atptour.com/en/scores/current/pari...
# 64  https://www.atptour.com/en/scores/archive/metz...
# 65
# 66
# 67
#
# [68 rows x 12 columns]
